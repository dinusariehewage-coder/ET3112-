# %% [markdown]
# <a href="https://colab.research.google.com/github/dinusariehewage-coder/ET3112-/blob/main/Q5(d).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# OpenCV built-in GaussianBlur
smoothed_cv = cv.GaussianBlur(img, (5, 5), sigmaX=2)

# Display
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(smoothed_manual, cmap='gray')
plt.title('Manual Gaussian')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(smoothed_cv, cmap='gray')
plt.title('OpenCV GaussianBlur')
plt.axis('off')
plt.show()
