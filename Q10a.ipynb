# %% [markdown]
# <a href="https://colab.research.google.com/github/dinusariehewage-coder/ET3112-/blob/main/Q10a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def bilateral_filter_manual(img, diameter, sigma_s, sigma_r):
    r = diameter // 2
    padded = np.pad(img, r, mode='reflect')
    output = np.zeros_like(img, dtype=np.float64)

    x, y = np.mgrid[-r:r+1, -r:r+1]
    spatial = np.exp(-(x**2 + y**2) / (2 * sigma_s**2))

    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            region = padded[i:i+diameter, j:j+diameter]
            center = padded[i+r, j+r]

            range_w = np.exp(-((region - center)**2) / (2 * sigma_r**2))
            weights = spatial * range_w

            output[i, j] = np.sum(weights * region) / np.sum(weights)

    return np.uint8(output)

bilateral_manual = bilateral_filter_manual(img, 7, 5, 30)
