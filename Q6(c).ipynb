# %% [markdown]
# <a href="https://colab.research.google.com/github/dinusariehewage-coder/ET3112-/blob/main/Q6(c).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

size = 51
k = size // 2

x, y = np.meshgrid(np.arange(-k, k+1), np.arange(-k, k+1))

G = (1 / (2 * np.pi * sigma**2)) * np.exp(-(x**2 + y**2) / (2 * sigma**2))
Gx = -(x / sigma**2) * G

fig = plt.figure(figsize=(7, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, Gx, cmap='coolwarm')
ax.set_title('Derivative of Gaussian (∂G/∂x)')
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.show()
